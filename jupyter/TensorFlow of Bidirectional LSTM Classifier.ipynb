# %%
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
learning_rate = 0.01
max_samples = 400000
batch_size = 128
display_step = 10

# %%
n_input = 28
n_steps = 28
n_hidden = 256
n_classes = 10

# %%
x = tf.placeholder("float",[None,n_steps,n_input])
y = tf.placeholder("float",[None,n_classes])

weights = tf.Variable(tf.random_normal([2*n_hidden,n_classes]))
biases = tf.Variable(tf.random_normal([n_classes]))

# %%
def BiRNN(x,weights,biases):
    x = tf.transpose(x,[1,0,2])
    x = tf.reshape(x,[-1,n_input])
    x = tf.split(x,n_steps)
    
    lstm_fw_cell = tf.contrib.rnn.BasicLSTMCell(n_hidden,forget_bias=1.0)
    lstm_bw_cell = tf.contrib.rnn.BasicLSTMCell(n_hidden,forget_bias=1.0)
    
    outputs,_,_ = tf.contrib.rnn.static_bidirectional_rnn(lstm_fw_cell,
                                                         lstm_bw_cell,x,
                                                         dtype=tf.float32)
    return tf.matmul(outputs[-1],weights)+biases

# %%
pred = BiRNN(x,weights,biases)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred,
                                                             labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

correct_pred = tf.equal(tf.argmax(pred,1),tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred,tf.float32))

init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    step = 1
    while step*batch_size < max_samples:
        batch_x,batch_y = mnist.train.next_batch(batch_size)
        batch_x = batch_x.reshape((batch_size,n_steps,n_input))
        sess.run(optimizer,feed_dict={x:batch_x,y:batch_y})
        if step%display_step==0:
            acc = sess.run(accuracy,feed_dict={x:batch_x,y:batch_y})
            loss = sess.run(cost,feed_dict={x:batch_x,y:batch_y})
            print("Iter "+str(step*batch_size)+",Minibatch Loss= "+\
                 "{:.6f}".format(loss)+",Training Accuracy= "+\
                 "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    test_len = 10000
    test_data = mnist.test.images[:test_len].reshape((-1,n_steps,n_input))
    test_label = mnist.test.labels[:test_len]
    print("Testing Accuracy:",
         sess.run(accuracy,feed_dict={x:test_data,y:test_label}))
# Out:
# Iter 1280,Minibatch Loss= 2.144076,Training Accuracy= 0.25000
# Iter 2560,Minibatch Loss= 1.091081,Training Accuracy= 0.63281
# Iter 3840,Minibatch Loss= 0.813613,Training Accuracy= 0.70312
# Iter 5120,Minibatch Loss= 0.779051,Training Accuracy= 0.74219
# Iter 6400,Minibatch Loss= 0.474857,Training Accuracy= 0.82812
# Iter 7680,Minibatch Loss= 0.454536,Training Accuracy= 0.89062
# Iter 8960,Minibatch Loss= 0.266416,Training Accuracy= 0.90625
# Iter 10240,Minibatch Loss= 0.333240,Training Accuracy= 0.91406
# Iter 11520,Minibatch Loss= 0.298826,Training Accuracy= 0.89062
# Iter 12800,Minibatch Loss= 0.181717,Training Accuracy= 0.93750
# Iter 14080,Minibatch Loss= 0.279592,Training Accuracy= 0.88281
# Iter 15360,Minibatch Loss= 0.107583,Training Accuracy= 0.96875
# Iter 16640,Minibatch Loss= 0.230164,Training Accuracy= 0.92188
# Iter 17920,Minibatch Loss= 0.155943,Training Accuracy= 0.94531
# Iter 19200,Minibatch Loss= 0.194644,Training Accuracy= 0.94531
# Iter 20480,Minibatch Loss= 0.079134,Training Accuracy= 0.96875
# Iter 21760,Minibatch Loss= 0.262544,Training Accuracy= 0.92188
# Iter 23040,Minibatch Loss= 0.120966,Training Accuracy= 0.97656
# Iter 24320,Minibatch Loss= 0.238571,Training Accuracy= 0.91406
# Iter 25600,Minibatch Loss= 0.086016,Training Accuracy= 0.98438
# Iter 26880,Minibatch Loss= 0.139340,Training Accuracy= 0.93750
# Iter 28160,Minibatch Loss= 0.086257,Training Accuracy= 0.98438
# Iter 29440,Minibatch Loss= 0.116781,Training Accuracy= 0.95312
# Iter 30720,Minibatch Loss= 0.110078,Training Accuracy= 0.97656
# Iter 32000,Minibatch Loss= 0.130240,Training Accuracy= 0.96094
# Iter 33280,Minibatch Loss= 0.127713,Training Accuracy= 0.96094
# Iter 34560,Minibatch Loss= 0.106753,Training Accuracy= 0.96094
# Iter 35840,Minibatch Loss= 0.223362,Training Accuracy= 0.94531
# Iter 37120,Minibatch Loss= 0.123867,Training Accuracy= 0.96094
# Iter 38400,Minibatch Loss= 0.066540,Training Accuracy= 0.97656
# Iter 39680,Minibatch Loss= 0.170558,Training Accuracy= 0.93750
# Iter 40960,Minibatch Loss= 0.126681,Training Accuracy= 0.94531
# Iter 42240,Minibatch Loss= 0.095151,Training Accuracy= 0.96094
# Iter 43520,Minibatch Loss= 0.098154,Training Accuracy= 0.94531
# Iter 44800,Minibatch Loss= 0.065455,Training Accuracy= 0.97656
# Iter 46080,Minibatch Loss= 0.102477,Training Accuracy= 0.98438
# Iter 47360,Minibatch Loss= 0.141730,Training Accuracy= 0.96094
# Iter 48640,Minibatch Loss= 0.080782,Training Accuracy= 0.97656
# Iter 49920,Minibatch Loss= 0.048431,Training Accuracy= 0.97656
# Iter 51200,Minibatch Loss= 0.034521,Training Accuracy= 0.99219
# Iter 52480,Minibatch Loss= 0.051070,Training Accuracy= 0.97656
# Iter 53760,Minibatch Loss= 0.056537,Training Accuracy= 0.97656
# Iter 55040,Minibatch Loss= 0.086700,Training Accuracy= 0.97656
# Iter 56320,Minibatch Loss= 0.040323,Training Accuracy= 0.99219
# Iter 57600,Minibatch Loss= 0.047107,Training Accuracy= 0.98438
# Iter 58880,Minibatch Loss= 0.099575,Training Accuracy= 0.96875
# Iter 60160,Minibatch Loss= 0.043958,Training Accuracy= 0.99219
# Iter 61440,Minibatch Loss= 0.022492,Training Accuracy= 0.99219
# Iter 62720,Minibatch Loss= 0.063759,Training Accuracy= 0.99219
# Iter 64000,Minibatch Loss= 0.046849,Training Accuracy= 0.99219
# Iter 65280,Minibatch Loss= 0.029944,Training Accuracy= 0.99219
# Iter 66560,Minibatch Loss= 0.049487,Training Accuracy= 0.98438
# Iter 67840,Minibatch Loss= 0.106540,Training Accuracy= 0.97656
# Iter 69120,Minibatch Loss= 0.084063,Training Accuracy= 0.97656
# Iter 70400,Minibatch Loss= 0.043068,Training Accuracy= 1.00000
# Iter 71680,Minibatch Loss= 0.116467,Training Accuracy= 0.97656
# Iter 72960,Minibatch Loss= 0.030825,Training Accuracy= 0.99219
# Iter 74240,Minibatch Loss= 0.031779,Training Accuracy= 0.99219
# Iter 75520,Minibatch Loss= 0.076429,Training Accuracy= 0.98438
# Iter 76800,Minibatch Loss= 0.035926,Training Accuracy= 0.99219
# Iter 78080,Minibatch Loss= 0.010164,Training Accuracy= 1.00000
# Iter 79360,Minibatch Loss= 0.123194,Training Accuracy= 0.97656
# Iter 80640,Minibatch Loss= 0.011969,Training Accuracy= 1.00000
# Iter 81920,Minibatch Loss= 0.057440,Training Accuracy= 0.96875
# Iter 83200,Minibatch Loss= 0.025403,Training Accuracy= 1.00000
# Iter 84480,Minibatch Loss= 0.090251,Training Accuracy= 0.96875
# Iter 85760,Minibatch Loss= 0.093832,Training Accuracy= 0.96875
# Iter 87040,Minibatch Loss= 0.017961,Training Accuracy= 0.99219
# Iter 88320,Minibatch Loss= 0.037575,Training Accuracy= 0.99219
# Iter 89600,Minibatch Loss= 0.095558,Training Accuracy= 0.97656
# Iter 90880,Minibatch Loss= 0.048099,Training Accuracy= 0.98438
# Iter 92160,Minibatch Loss= 0.108232,Training Accuracy= 0.98438
# Iter 93440,Minibatch Loss= 0.040382,Training Accuracy= 0.98438
# Iter 94720,Minibatch Loss= 0.107827,Training Accuracy= 0.96875
# Iter 96000,Minibatch Loss= 0.062881,Training Accuracy= 0.97656
# Iter 97280,Minibatch Loss= 0.033542,Training Accuracy= 0.98438
# Iter 98560,Minibatch Loss= 0.045753,Training Accuracy= 0.98438
# Iter 99840,Minibatch Loss= 0.044446,Training Accuracy= 0.97656
# Iter 101120,Minibatch Loss= 0.048220,Training Accuracy= 0.99219
# Iter 102400,Minibatch Loss= 0.090635,Training Accuracy= 0.96094
# Iter 103680,Minibatch Loss= 0.034368,Training Accuracy= 0.99219
# Iter 104960,Minibatch Loss= 0.031305,Training Accuracy= 0.99219
# Iter 106240,Minibatch Loss= 0.045587,Training Accuracy= 0.99219
# Iter 107520,Minibatch Loss= 0.070108,Training Accuracy= 0.97656
# Iter 108800,Minibatch Loss= 0.043837,Training Accuracy= 0.99219
# Iter 110080,Minibatch Loss= 0.076425,Training Accuracy= 0.98438
# Iter 111360,Minibatch Loss= 0.033717,Training Accuracy= 0.99219
# Iter 112640,Minibatch Loss= 0.011350,Training Accuracy= 1.00000
# Iter 113920,Minibatch Loss= 0.032909,Training Accuracy= 0.99219
# Iter 115200,Minibatch Loss= 0.026171,Training Accuracy= 0.99219
# Iter 116480,Minibatch Loss= 0.032957,Training Accuracy= 0.99219
# Iter 117760,Minibatch Loss= 0.022565,Training Accuracy= 0.99219
# Iter 119040,Minibatch Loss= 0.046307,Training Accuracy= 0.99219
# Iter 120320,Minibatch Loss= 0.061879,Training Accuracy= 0.99219
# Iter 121600,Minibatch Loss= 0.046918,Training Accuracy= 0.99219
# Iter 122880,Minibatch Loss= 0.055047,Training Accuracy= 0.97656
# Iter 124160,Minibatch Loss= 0.031877,Training Accuracy= 0.98438
# Iter 125440,Minibatch Loss= 0.022099,Training Accuracy= 0.99219
# Iter 126720,Minibatch Loss= 0.021606,Training Accuracy= 1.00000
# Iter 128000,Minibatch Loss= 0.023499,Training Accuracy= 0.99219
# Iter 129280,Minibatch Loss= 0.006527,Training Accuracy= 1.00000
# Iter 130560,Minibatch Loss= 0.026835,Training Accuracy= 0.99219
# Iter 131840,Minibatch Loss= 0.058165,Training Accuracy= 0.96875
# Iter 133120,Minibatch Loss= 0.021000,Training Accuracy= 1.00000
# Iter 134400,Minibatch Loss= 0.022636,Training Accuracy= 1.00000
# Iter 135680,Minibatch Loss= 0.009445,Training Accuracy= 1.00000
# Iter 136960,Minibatch Loss= 0.068701,Training Accuracy= 0.99219
# Iter 138240,Minibatch Loss= 0.053168,Training Accuracy= 0.97656
# Iter 139520,Minibatch Loss= 0.052790,Training Accuracy= 0.97656
# Iter 140800,Minibatch Loss= 0.079223,Training Accuracy= 0.97656
# Iter 142080,Minibatch Loss= 0.029414,Training Accuracy= 1.00000
# Iter 143360,Minibatch Loss= 0.018856,Training Accuracy= 1.00000
# Iter 144640,Minibatch Loss= 0.036431,Training Accuracy= 0.99219
# Iter 145920,Minibatch Loss= 0.024180,Training Accuracy= 0.99219
# Iter 147200,Minibatch Loss= 0.040233,Training Accuracy= 0.98438
# Iter 148480,Minibatch Loss= 0.025429,Training Accuracy= 0.99219
# Iter 149760,Minibatch Loss= 0.013276,Training Accuracy= 1.00000
# Iter 151040,Minibatch Loss= 0.016646,Training Accuracy= 1.00000
# Iter 152320,Minibatch Loss= 0.016095,Training Accuracy= 0.99219
# Iter 153600,Minibatch Loss= 0.036195,Training Accuracy= 0.99219
# Iter 154880,Minibatch Loss= 0.019413,Training Accuracy= 0.99219
# Iter 156160,Minibatch Loss= 0.043972,Training Accuracy= 0.99219
# Iter 157440,Minibatch Loss= 0.034407,Training Accuracy= 0.98438
# Iter 158720,Minibatch Loss= 0.010699,Training Accuracy= 1.00000
# Iter 160000,Minibatch Loss= 0.019824,Training Accuracy= 1.00000
# Iter 161280,Minibatch Loss= 0.062568,Training Accuracy= 0.99219
# Iter 162560,Minibatch Loss= 0.069909,Training Accuracy= 0.99219
# Iter 163840,Minibatch Loss= 0.048364,Training Accuracy= 0.98438
# Iter 165120,Minibatch Loss= 0.069923,Training Accuracy= 0.96875
# Iter 166400,Minibatch Loss= 0.010938,Training Accuracy= 1.00000
# Iter 167680,Minibatch Loss= 0.015356,Training Accuracy= 1.00000
# Iter 168960,Minibatch Loss= 0.013261,Training Accuracy= 1.00000
# Iter 170240,Minibatch Loss= 0.015548,Training Accuracy= 1.00000
# Iter 171520,Minibatch Loss= 0.011175,Training Accuracy= 1.00000
# Iter 172800,Minibatch Loss= 0.019537,Training Accuracy= 0.99219
# Iter 174080,Minibatch Loss= 0.119964,Training Accuracy= 0.97656
# Iter 175360,Minibatch Loss= 0.039738,Training Accuracy= 0.97656
# Iter 176640,Minibatch Loss= 0.040198,Training Accuracy= 0.99219
# Iter 177920,Minibatch Loss= 0.012384,Training Accuracy= 1.00000
# Iter 179200,Minibatch Loss= 0.014540,Training Accuracy= 1.00000
# Iter 180480,Minibatch Loss= 0.008855,Training Accuracy= 1.00000
# Iter 181760,Minibatch Loss= 0.041706,Training Accuracy= 0.97656
# Iter 183040,Minibatch Loss= 0.030443,Training Accuracy= 0.98438
# Iter 184320,Minibatch Loss= 0.034018,Training Accuracy= 0.99219
# Iter 185600,Minibatch Loss= 0.083714,Training Accuracy= 0.98438
# Iter 186880,Minibatch Loss= 0.023323,Training Accuracy= 0.99219
# Iter 188160,Minibatch Loss= 0.098567,Training Accuracy= 0.97656
# Iter 189440,Minibatch Loss= 0.062870,Training Accuracy= 0.97656
# Iter 190720,Minibatch Loss= 0.039584,Training Accuracy= 0.97656
# Iter 192000,Minibatch Loss= 0.015988,Training Accuracy= 1.00000
# Iter 193280,Minibatch Loss= 0.056271,Training Accuracy= 0.97656
# Iter 194560,Minibatch Loss= 0.044816,Training Accuracy= 0.99219
# Iter 195840,Minibatch Loss= 0.038114,Training Accuracy= 0.99219
# Iter 197120,Minibatch Loss= 0.058796,Training Accuracy= 0.97656
# Iter 198400,Minibatch Loss= 0.047673,Training Accuracy= 0.99219
# Iter 199680,Minibatch Loss= 0.010316,Training Accuracy= 1.00000
# Iter 200960,Minibatch Loss= 0.031118,Training Accuracy= 0.99219
# Iter 202240,Minibatch Loss= 0.013483,Training Accuracy= 1.00000
# Iter 203520,Minibatch Loss= 0.032179,Training Accuracy= 0.99219
# Iter 204800,Minibatch Loss= 0.020172,Training Accuracy= 1.00000
# Iter 206080,Minibatch Loss= 0.027318,Training Accuracy= 0.99219
# Iter 207360,Minibatch Loss= 0.002780,Training Accuracy= 1.00000
# Iter 208640,Minibatch Loss= 0.036671,Training Accuracy= 0.99219
# Iter 209920,Minibatch Loss= 0.024510,Training Accuracy= 1.00000
# Iter 211200,Minibatch Loss= 0.043804,Training Accuracy= 0.98438
# Iter 212480,Minibatch Loss= 0.053476,Training Accuracy= 0.99219
# Iter 213760,Minibatch Loss= 0.006900,Training Accuracy= 1.00000
# Iter 215040,Minibatch Loss= 0.014336,Training Accuracy= 0.99219
# Iter 216320,Minibatch Loss= 0.006457,Training Accuracy= 1.00000
# Iter 217600,Minibatch Loss= 0.005320,Training Accuracy= 1.00000
# Iter 218880,Minibatch Loss= 0.026976,Training Accuracy= 0.98438
# Iter 220160,Minibatch Loss= 0.027268,Training Accuracy= 0.99219
# Iter 221440,Minibatch Loss= 0.011489,Training Accuracy= 1.00000
# Iter 222720,Minibatch Loss= 0.025433,Training Accuracy= 0.98438
# Iter 224000,Minibatch Loss= 0.005470,Training Accuracy= 1.00000
# Iter 225280,Minibatch Loss= 0.095443,Training Accuracy= 0.98438
# Iter 226560,Minibatch Loss= 0.033783,Training Accuracy= 0.99219
# Iter 227840,Minibatch Loss= 0.055621,Training Accuracy= 0.97656
# Iter 229120,Minibatch Loss= 0.015177,Training Accuracy= 1.00000
# Iter 230400,Minibatch Loss= 0.010931,Training Accuracy= 1.00000
# Iter 231680,Minibatch Loss= 0.013427,Training Accuracy= 1.00000
# Iter 232960,Minibatch Loss= 0.042144,Training Accuracy= 0.99219
# Iter 234240,Minibatch Loss= 0.033276,Training Accuracy= 0.98438
# Iter 235520,Minibatch Loss= 0.041182,Training Accuracy= 0.99219
# Iter 236800,Minibatch Loss= 0.034087,Training Accuracy= 0.99219
# Iter 238080,Minibatch Loss= 0.004047,Training Accuracy= 1.00000
# Iter 239360,Minibatch Loss= 0.033792,Training Accuracy= 0.99219
# Iter 240640,Minibatch Loss= 0.016100,Training Accuracy= 1.00000
# Iter 241920,Minibatch Loss= 0.010414,Training Accuracy= 0.99219
# Iter 243200,Minibatch Loss= 0.012789,Training Accuracy= 1.00000
# Iter 244480,Minibatch Loss= 0.008918,Training Accuracy= 1.00000
# Iter 245760,Minibatch Loss= 0.007503,Training Accuracy= 1.00000
# Iter 247040,Minibatch Loss= 0.005177,Training Accuracy= 1.00000
# Iter 248320,Minibatch Loss= 0.061750,Training Accuracy= 0.98438
# Iter 249600,Minibatch Loss= 0.010340,Training Accuracy= 1.00000
# Iter 250880,Minibatch Loss= 0.012792,Training Accuracy= 1.00000
# Iter 252160,Minibatch Loss= 0.015139,Training Accuracy= 0.99219
# Iter 253440,Minibatch Loss= 0.099833,Training Accuracy= 0.98438
# Iter 254720,Minibatch Loss= 0.041700,Training Accuracy= 0.98438
# Iter 256000,Minibatch Loss= 0.022283,Training Accuracy= 0.99219
# Iter 257280,Minibatch Loss= 0.003578,Training Accuracy= 1.00000
# Iter 258560,Minibatch Loss= 0.020425,Training Accuracy= 1.00000
# Iter 259840,Minibatch Loss= 0.011255,Training Accuracy= 1.00000
# Iter 261120,Minibatch Loss= 0.013404,Training Accuracy= 1.00000
# Iter 262400,Minibatch Loss= 0.004324,Training Accuracy= 1.00000
# Iter 263680,Minibatch Loss= 0.004636,Training Accuracy= 1.00000
# Iter 264960,Minibatch Loss= 0.007557,Training Accuracy= 1.00000
# Iter 266240,Minibatch Loss= 0.006026,Training Accuracy= 1.00000
# Iter 267520,Minibatch Loss= 0.005490,Training Accuracy= 1.00000
# Iter 268800,Minibatch Loss= 0.037498,Training Accuracy= 0.98438
# Iter 270080,Minibatch Loss= 0.021537,Training Accuracy= 0.99219
# Iter 271360,Minibatch Loss= 0.020812,Training Accuracy= 0.98438
# Iter 272640,Minibatch Loss= 0.004585,Training Accuracy= 1.00000
# Iter 273920,Minibatch Loss= 0.020076,Training Accuracy= 1.00000
# Iter 275200,Minibatch Loss= 0.013465,Training Accuracy= 1.00000
# Iter 276480,Minibatch Loss= 0.046550,Training Accuracy= 0.99219
# Iter 277760,Minibatch Loss= 0.005887,Training Accuracy= 1.00000
# Iter 279040,Minibatch Loss= 0.021449,Training Accuracy= 0.99219
# Iter 280320,Minibatch Loss= 0.007446,Training Accuracy= 1.00000
# Iter 281600,Minibatch Loss= 0.009731,Training Accuracy= 1.00000
# Iter 282880,Minibatch Loss= 0.030787,Training Accuracy= 0.99219
# Iter 284160,Minibatch Loss= 0.025472,Training Accuracy= 0.99219
# Iter 285440,Minibatch Loss= 0.006272,Training Accuracy= 1.00000
# Iter 286720,Minibatch Loss= 0.012804,Training Accuracy= 1.00000
# Iter 288000,Minibatch Loss= 0.029795,Training Accuracy= 0.98438
# Iter 289280,Minibatch Loss= 0.017945,Training Accuracy= 0.99219
# Iter 290560,Minibatch Loss= 0.045504,Training Accuracy= 0.99219
# Iter 291840,Minibatch Loss= 0.039028,Training Accuracy= 0.98438
# Iter 293120,Minibatch Loss= 0.018658,Training Accuracy= 1.00000
# Iter 294400,Minibatch Loss= 0.025255,Training Accuracy= 0.99219
# Iter 295680,Minibatch Loss= 0.031465,Training Accuracy= 0.99219
# Iter 296960,Minibatch Loss= 0.009293,Training Accuracy= 1.00000
# Iter 298240,Minibatch Loss= 0.021575,Training Accuracy= 0.99219
# Iter 299520,Minibatch Loss= 0.016999,Training Accuracy= 0.99219
# Iter 300800,Minibatch Loss= 0.050578,Training Accuracy= 0.98438
# Iter 302080,Minibatch Loss= 0.018944,Training Accuracy= 0.99219
# Iter 303360,Minibatch Loss= 0.048523,Training Accuracy= 0.99219
# Iter 304640,Minibatch Loss= 0.024754,Training Accuracy= 0.99219
# Iter 305920,Minibatch Loss= 0.014289,Training Accuracy= 1.00000
# Iter 307200,Minibatch Loss= 0.028317,Training Accuracy= 0.98438
# Iter 308480,Minibatch Loss= 0.088905,Training Accuracy= 0.97656
# Iter 309760,Minibatch Loss= 0.013194,Training Accuracy= 1.00000
# Iter 311040,Minibatch Loss= 0.039270,Training Accuracy= 0.98438
# Iter 312320,Minibatch Loss= 0.035763,Training Accuracy= 0.99219
# Iter 313600,Minibatch Loss= 0.007702,Training Accuracy= 1.00000
# Iter 314880,Minibatch Loss= 0.026029,Training Accuracy= 0.99219
# Iter 316160,Minibatch Loss= 0.030133,Training Accuracy= 0.98438
# Iter 317440,Minibatch Loss= 0.034027,Training Accuracy= 0.99219
# Iter 318720,Minibatch Loss= 0.001781,Training Accuracy= 1.00000
# Iter 320000,Minibatch Loss= 0.002247,Training Accuracy= 1.00000
# Iter 321280,Minibatch Loss= 0.007109,Training Accuracy= 1.00000
# Iter 322560,Minibatch Loss= 0.010616,Training Accuracy= 0.99219
# Iter 323840,Minibatch Loss= 0.017789,Training Accuracy= 0.99219
# Iter 325120,Minibatch Loss= 0.007717,Training Accuracy= 1.00000
# Iter 326400,Minibatch Loss= 0.009042,Training Accuracy= 1.00000
# Iter 327680,Minibatch Loss= 0.000937,Training Accuracy= 1.00000
# Iter 328960,Minibatch Loss= 0.034532,Training Accuracy= 0.99219
# Iter 330240,Minibatch Loss= 0.026685,Training Accuracy= 0.99219
# Iter 331520,Minibatch Loss= 0.014411,Training Accuracy= 1.00000
# Iter 332800,Minibatch Loss= 0.012307,Training Accuracy= 1.00000
# Iter 334080,Minibatch Loss= 0.010079,Training Accuracy= 1.00000
# Iter 335360,Minibatch Loss= 0.014670,Training Accuracy= 0.99219
# Iter 336640,Minibatch Loss= 0.007379,Training Accuracy= 1.00000
# Iter 337920,Minibatch Loss= 0.022446,Training Accuracy= 0.98438
# Iter 339200,Minibatch Loss= 0.003948,Training Accuracy= 1.00000
# Iter 340480,Minibatch Loss= 0.008504,Training Accuracy= 1.00000
# Iter 341760,Minibatch Loss= 0.013078,Training Accuracy= 1.00000
# Iter 343040,Minibatch Loss= 0.039572,Training Accuracy= 0.99219
# Iter 344320,Minibatch Loss= 0.012958,Training Accuracy= 1.00000
# Iter 345600,Minibatch Loss= 0.015595,Training Accuracy= 0.99219
# Iter 346880,Minibatch Loss= 0.029073,Training Accuracy= 0.99219
# Iter 348160,Minibatch Loss= 0.051589,Training Accuracy= 0.99219
# Iter 349440,Minibatch Loss= 0.024883,Training Accuracy= 0.99219
# Iter 350720,Minibatch Loss= 0.030056,Training Accuracy= 0.98438
# Iter 352000,Minibatch Loss= 0.007762,Training Accuracy= 1.00000
# Iter 353280,Minibatch Loss= 0.004793,Training Accuracy= 1.00000
# Iter 354560,Minibatch Loss= 0.004920,Training Accuracy= 1.00000
# Iter 355840,Minibatch Loss= 0.004929,Training Accuracy= 1.00000
# Iter 357120,Minibatch Loss= 0.008086,Training Accuracy= 1.00000
# Iter 358400,Minibatch Loss= 0.025121,Training Accuracy= 0.99219
# Iter 359680,Minibatch Loss= 0.066139,Training Accuracy= 0.97656
# Iter 360960,Minibatch Loss= 0.007557,Training Accuracy= 1.00000
# Iter 362240,Minibatch Loss= 0.012330,Training Accuracy= 1.00000
# Iter 363520,Minibatch Loss= 0.005744,Training Accuracy= 1.00000
# Iter 364800,Minibatch Loss= 0.012856,Training Accuracy= 0.99219
# Iter 366080,Minibatch Loss= 0.014198,Training Accuracy= 1.00000
# Iter 367360,Minibatch Loss= 0.008554,Training Accuracy= 1.00000
# Iter 368640,Minibatch Loss= 0.011154,Training Accuracy= 0.99219
# Iter 369920,Minibatch Loss= 0.019701,Training Accuracy= 1.00000
# Iter 371200,Minibatch Loss= 0.003792,Training Accuracy= 1.00000
# Iter 372480,Minibatch Loss= 0.011277,Training Accuracy= 0.99219
# Iter 373760,Minibatch Loss= 0.005225,Training Accuracy= 1.00000
# Iter 375040,Minibatch Loss= 0.001843,Training Accuracy= 1.00000
# Iter 376320,Minibatch Loss= 0.015172,Training Accuracy= 0.99219
# Iter 377600,Minibatch Loss= 0.004783,Training Accuracy= 1.00000
# Iter 378880,Minibatch Loss= 0.006489,Training Accuracy= 1.00000
# Iter 380160,Minibatch Loss= 0.067228,Training Accuracy= 0.98438
# Iter 381440,Minibatch Loss= 0.011909,Training Accuracy= 1.00000
# Iter 382720,Minibatch Loss= 0.012474,Training Accuracy= 1.00000
# Iter 384000,Minibatch Loss= 0.031864,Training Accuracy= 0.99219
# Iter 385280,Minibatch Loss= 0.008620,Training Accuracy= 1.00000
# Iter 386560,Minibatch Loss= 0.006938,Training Accuracy= 1.00000
# Iter 387840,Minibatch Loss= 0.002932,Training Accuracy= 1.00000
# Iter 389120,Minibatch Loss= 0.007454,Training Accuracy= 1.00000
# Iter 390400,Minibatch Loss= 0.008543,Training Accuracy= 1.00000
# Iter 391680,Minibatch Loss= 0.058193,Training Accuracy= 0.98438
# Iter 392960,Minibatch Loss= 0.002952,Training Accuracy= 1.00000
# Iter 394240,Minibatch Loss= 0.015810,Training Accuracy= 1.00000
# Iter 395520,Minibatch Loss= 0.012494,Training Accuracy= 0.99219
# Iter 396800,Minibatch Loss= 0.007948,Training Accuracy= 0.99219
# Iter 398080,Minibatch Loss= 0.005960,Training Accuracy= 1.00000
# Iter 399360,Minibatch Loss= 0.049659,Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy: 0.9856
